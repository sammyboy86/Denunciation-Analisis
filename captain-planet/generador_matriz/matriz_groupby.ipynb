# %%
import pandas as pd
import numpy as np

#aca poner el path del dataset de la paot
df_denuncias = pd.read_csv(r'C:\Users\samue\OneDrive\Documents\GitHub\captain_planet_sammy\captain-planet\data\raw\df_paot_con_limpieza.csv', encoding='utf-8')
df_denuncias[["fecha_de_recepcion", "fecha_de_ratificacion", "fecha_de_turno", "fecha_de_admision/radicacion", "fecha_de_conclusion"]] = df_denuncias[["fecha_de_recepcion", "fecha_de_ratificacion", "fecha_de_turno", "fecha_de_admision/radicacion", "fecha_de_conclusion"]].apply(pd.to_datetime, errors = 'coerce', infer_datetime_format=True)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_12772\2926675137.py:5: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_denuncias = pd.read_csv(r'C:\Users\samue\OneDrive\Documents\GitHub\captain_planet_sammy\captain-planet\data\raw\df_paot_con_limpieza.csv', encoding='utf-8')

# %%
df_denuncias['anio-mes-admision/radicacion'] = df_denuncias['fecha_de_admision/radicacion'].dt.strftime('%Y-%m')
df_denuncias['anio-mes-conclusion'] = df_denuncias['fecha_de_conclusion'].dt.strftime('%Y-%m')

# %%
matriz = df_denuncias.groupby(['alcaldia','estatus','tipo_de_denuncia', 'materia','medio_de_recepcion','regimen_propiedad','area_responsable','anio-mes-admision/radicacion','anio-mes-conclusion'], dropna=False).count()

# %%
matriz_1 = matriz[['id_denuncia']]

# %%
matriz_1.reset_index(inplace=True)

# %%
matriz_1.rename(columns = {'id_denuncia':'num_denuncias'}, inplace = True)
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_12772\2297195265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matriz_1.rename(columns = {'id_denuncia':'num_denuncias'}, inplace = True)

# %%
matriz_1
# Out:
#              alcaldia      estatus    tipo_de_denuncia  \
# 0      alvaro obregon    Concluida  Denuncia ciudadana
# 1      alvaro obregon    Concluida  Denuncia ciudadana
# 2      alvaro obregon    Concluida  Denuncia ciudadana
# 3      alvaro obregon    Concluida  Denuncia ciudadana
# 4      alvaro obregon    Concluida  Denuncia ciudadana
# ...               ...          ...                 ...
# 42878      xochimilco  No admitida  Denuncia ciudadana
# 42879      xochimilco  No admitida  Denuncia ciudadana
# 42880      xochimilco  No admitida  Denuncia ciudadana
# 42881      xochimilco  No admitida  Denuncia ciudadana
# 42882      xochimilco  No admitida  Denuncia ciudadana
#
#                               materia      medio_de_recepcion  \
# 0              Afectación al Arbolado                 Escrita
# 1              Afectación al Arbolado                Internet
# 2              Afectación al Arbolado                Internet
# ...

# %%
matriz_1.to_csv(r'C:\Users\samue\OneDrive\Documents\GitHub\captain_planet_sammy\captain-planet\data\clean\matriz_4.csv')
