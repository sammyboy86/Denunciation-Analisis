# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import matplotlib as mpl
import matplotlib.pyplot as plt   # data visualization
import seaborn as sns             # statistical data visualization

# %%
df = pd.read_csv(r'C:\Users\samue\OneDrive\Documents\GitHub\captain_planet_sammy\captain-planet\data\clean\matriz_con_carpetas.csv', encoding='utf-8', low_memory=False)
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])
# Out:
#               alcaldia           estatus    tipo_de_denuncia  \
# 0       alvaro obregon         Concluida  Denuncia ciudadana
# 1       alvaro obregon         Concluida  Denuncia ciudadana
# 2       alvaro obregon         Concluida  Denuncia ciudadana
# 3       alvaro obregon         Concluida  Denuncia ciudadana
# 4       alvaro obregon         Concluida  Denuncia ciudadana
# ...                ...               ...                 ...
# 594233      xochimilco  En investigación  Denuncia ciudadana
# 594234      xochimilco  En investigación  Denuncia ciudadana
# 594235      xochimilco  En investigación  Denuncia ciudadana
# 594236      xochimilco  En investigación  Denuncia ciudadana
# 594237      xochimilco  En investigación  Denuncia ciudadana
#
#                        materia medio_de_recepcion regimen_propiedad  \
# 0       Afectación al Arbolado           Internet               NaN
# 1       Afectación al Arbolado           Internet               NaN
# 2       Afectación al Arbolado           Internet               NaN
# 3       Afectación al Arbolado           Internet               NaN
# 4       Afectación al Arbolado           Internet               NaN
# ...                        ...                ...               ...
# 594233         Maltrato Animal           Internet               NaN
# 594234         Maltrato Animal           Internet               NaN
# 594235         Maltrato Animal           Internet               NaN
# 594236         Maltrato Animal           Internet               NaN
# 594237         Maltrato Animal           Internet               NaN
#
#                                          area_responsable  \
# 0       Subprocuraduría Ambiental, de Protección y Bie...
# 1       Subprocuraduría Ambiental, de Protección y Bie...
# 2       Subprocuraduría Ambiental, de Protección y Bie...
# 3       Subprocuraduría Ambiental, de Protección y Bie...
# 4       Subprocuraduría Ambiental, de Protección y Bie...
# ...                                                   ...
# 594233  Subprocuraduría Ambiental, de Protección y Bie...
# 594234  Subprocuraduría Ambiental, de Protección y Bie...
# 594235  Subprocuraduría Ambiental, de Protección y Bie...
# 594236  Subprocuraduría Ambiental, de Protección y Bie...
# 594237  Subprocuraduría Ambiental, de Protección y Bie...
#
#        anio-mes-admision/radicacion anio-mes-conclusion  num_denuncias  \
# 0                           2020-01             2022-02              1
# 1                           2020-01             2022-02              1
# 2                           2020-01             2022-02              1
# 3                           2020-01             2022-02              1
# 4                           2020-01             2022-02              1
# ...                             ...                 ...            ...
# 594233                      2020-11                 NaN              1
# 594234                      2020-11                 NaN              1
# 594235                      2020-11                 NaN              1
# 594236                      2020-11                 NaN              1
# 594237                      2020-11                 NaN              1
#
#         alcaldiahechos fechainicio  \
# 0       alvaro obregon     2020-01
# 1       alvaro obregon     2020-01
# 2       alvaro obregon     2020-01
# 3       alvaro obregon     2020-01
# 4       alvaro obregon     2020-01
# ...                ...         ...
# 594233      xochimilco     2020-11
# 594234      xochimilco     2020-11
# 594235      xochimilco     2020-11
# 594236      xochimilco     2020-11
# 594237      xochimilco     2020-11
#
#                                                    delito  num_carpetas
# 0                                                  ABORTO             4
# 1       ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA P...            10
# 2                                      ABUSO DE CONFIANZA            22
# 3                                            ABUSO SEXUAL            17
# 4                                            ACOSO SEXUAL             5
# ...                                                   ...           ...
# 594233                             TENTATIVA DE EXTORSION             3
# 594234                             TENTATIVA DE HOMICIDIO             1
# 594235                            USURPACIÓN DE IDENTIDAD             2
# 594236                                          VIOLACION             2
# 594237                                 VIOLENCIA FAMILIAR            22
#
# [594238 rows x 14 columns]
